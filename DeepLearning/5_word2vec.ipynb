# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
print(words[1:50])
# Out:
# ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term', 'is', 'still', 'used', 'in', 'a', 'pejorative', 'way', 'to', 'describe', 'any', 'act', 'that', 'used', 'violent', 'means', 'to', 'destroy', 'the']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5244, 3082, 12, 6, 195, 2, 3136, 46, 59, 156]

# %%
# print(reverse_dictionary)
sentence = []
for i in range(0,20):
    sentence.append(reverse_dictionary[data[i]])
print(sentence)
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english']

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'term', 'as', 'of', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, 
                            biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.330449
# Nearest to first: starving, outlining, hale, crafted, chickens, cellar, voltages, elbaradei,
# Nearest to three: upa, dhtml, sayer, masses, residue, conversation, mjd, cuailnge,
# Nearest to had: atx, cambodia, lawlessness, mao, spock, lack, optimized, centurion,
# Nearest to there: sensation, clutter, nawaf, bolster, administrated, lewd, disproven, armament,
# Nearest to with: omnibus, artcyclopedia, instantaneous, televangelist, necks, chondrite, akron, scathing,
# Nearest to no: regaining, bryce, watson, booty, midwives, chocolat, raytheon, reconnection,
# Nearest to only: xin, ansbach, tonnes, apologies, pled, heralded, quod, abandonment,
# Nearest to four: arkansas, drawings, gramophone, velar, flares, spearhead, censorship, cebit,
# Nearest to not: czechs, speeding, nippon, fanatics, sharon, extinct, madhu, groceries,
# Nearest to so: egypt, giving, riga, disgraced, farmland, freikorps, efficiently, biochemical,
# Nearest to has: kankan, bittorrent, trs, najd, inquisitors, harlem, falcone, oxidize,
# Nearest to such: attractor, primitivism, polynomial, pine, pinchcliffe, svg, authoring, totleben,
# Nearest to be: inverness, ignite, decrees, bfi, joan, narrowing, flybys, playstation,
# Nearest to d: privations, langevin, texaco, neri, bindings, majorities, shamanistic, monroe,
# Nearest to more: jean, originators, messages, papandreou, refer, hilberg, shareholders, pythagoras,
# Nearest to was: valdemar, est, nsdap, vocabulary, codenamed, hittite, maja, chargers,
# Average loss at step 2000: 4.369074
# Average loss at step 4000: 3.864041
# Average loss at step 6000: 3.787426
# Average loss at step 8000: 3.683834
# Average loss at step 10000: 3.619197
# Nearest to first: starving, same, bottleneck, frei, elbaradei, dorset, mestizos, epsilon,
# Nearest to three: six, four, five, eight, seven, two, nine, zero,
# Nearest to had: has, have, was, were, definability, psychotherapy, distributed, been,
# Nearest to there: it, no, which, apa, he, they, chemistry, marsden,
# Nearest to with: for, by, between, in, strangle, samples, calorimeter, hottest,
# Nearest to no: homeomorphism, malawian, there, bryce, dickson, delicious, fukuda, regaining,
# Nearest to only: peptides, abatement, ansbach, must, used, apologies, semitic, spores,
# Nearest to four: six, three, five, seven, eight, nine, two, zero,
# Nearest to not: it, to, they, intracellular, we, precautionary, humanist, legislators,
# Nearest to so: giving, egypt, evansville, gloss, farmland, disgraced, targum, beverly,
# Nearest to has: had, have, is, was, bittorrent, invents, heterosexism, kankan,
# Nearest to such: polynomial, pinchcliffe, attractor, neil, cleaved, totleben, glycogen, bamiyan,
# Nearest to be: have, is, was, flybys, gluten, permissible, toonami, logo,
# Nearest to d: psychotic, upbeat, atlanteans, b, georges, langevin, anteater, eight,
# Nearest to more: very, crucified, strategies, originators, shareholders, smash, albion, infidels,
# Nearest to was: is, had, were, by, has, be, became, dash,
# Average loss at step 12000: 3.602537
# Average loss at step 14000: 3.573360
# Average loss at step 16000: 3.410101
# Average loss at step 18000: 3.459288
# Average loss at step 20000: 3.540598
# Nearest to first: last, same, starving, frei, mouth, dorset, bottleneck, city,
# Nearest to three: four, five, two, seven, six, eight, zero, nine,
# Nearest to had: has, have, was, were, pretenders, distributed, zbigniew, dore,
# Nearest to there: it, they, he, still, no, tinkering, often, which,
# Nearest to with: between, for, titanic, nervous, hass, in, botched, or,
# Nearest to no: malawian, there, it, dickson, homeomorphism, a, quartermaster, contend,
# Nearest to only: must, ceremony, abatement, mauritian, actually, spores, ansbach, mcdaniel,
# Nearest to four: seven, eight, five, six, three, nine, two, zero,
# Nearest to not: it, also, to, they, intracellular, we, be, harps,
# Nearest to so: giving, gloss, cognitive, beverly, shredded, quark, before, farmland,
# Nearest to has: had, is, have, was, invents, equine, bittorrent, rainier,
# Nearest to such: well, other, petronas, known, glycogen, these, far, pinchcliffe,
# Nearest to be: been, have, by, is, was, limnic, playstation, flybys,
# Nearest to d: b, russian, psychotic, apologist, van, frequent, republik, upbeat,
# Nearest to more: less, most, very, regency, louder, albion, screams, superorder,
# Nearest to was: is, were, had, became, has, be, been, bode,
# Average loss at step 22000: 3.500406
# Average loss at step 24000: 3.485996
# Average loss at step 26000: 3.479422
# Average loss at step 28000: 3.479533
# Average loss at step 30000: 3.503362
# Nearest to first: last, second, same, touchdowns, following, bottleneck, dactylic, frei,
# Nearest to three: four, five, seven, eight, two, six, nine, zero,
# Nearest to had: has, have, was, were, is, zbigniew, dirkjan, since,
# Nearest to there: they, it, he, still, often, she, no, usually,
# Nearest to with: between, in, for, or, by, nervous, glencoe, botched,
# Nearest to no: malawian, there, dickson, any, guarantee, a, homeomorphism, moire,
# Nearest to only: leisurely, attested, princeton, actually, ceremony, spores, microinstruction, must,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to not: they, it, intracellular, wadsworth, to, harps, shamir, humanist,
# Nearest to so: beverly, cognitive, before, dissection, farmland, if, geostationary, quark,
# Nearest to has: had, have, is, was, lauder, invents, since, rectangles,
# Nearest to such: well, these, known, other, regarded, campaigners, attractor, vacuum,
# Nearest to be: been, have, were, was, is, accidentals, limnic, permissible,
# Nearest to d: b, psychotic, apologist, hydrosphere, republik, activating, van, judoka,
# Nearest to more: less, very, most, outfielder, regency, screams, requirements, cheaply,
# Nearest to was: is, had, became, were, has, been, quimby, when,
# Average loss at step 32000: 3.504061
# Average loss at step 34000: 3.491052
# Average loss at step 36000: 3.455799
# Average loss at step 38000: 3.302142
# Average loss at step 40000: 3.426912
# Nearest to first: second, last, same, ballot, microtubule, gesellschaft, bottleneck, frei,
# Nearest to three: four, two, five, seven, six, eight, nine, zero,
# Nearest to had: has, have, was, were, pretenders, since, been, became,
# Nearest to there: they, it, she, he, often, usually, still, no,
# Nearest to with: between, glencoe, by, titanic, kinshasa, when, in, typhoid,
# Nearest to no: any, there, malawian, homeomorphism, dickson, guarantee, a, supp,
# Nearest to only: leisurely, actually, rated, princeton, childbirth, scored, microinstruction, ceremony,
# Nearest to four: six, eight, three, five, seven, two, nine, one,
# Nearest to not: they, it, still, now, also, intracellular, wadsworth, usually,
# Nearest to so: menelik, amazonas, installing, ammo, fixing, norad, entropy, sometime,
# Nearest to has: had, have, is, was, invents, waited, lauder, equine,
# Nearest to such: well, known, these, regarded, like, campaigners, incomplete, other,
# Nearest to be: have, been, were, was, being, is, are, limnic,
# Nearest to d: b, UNK, psychotic, van, hydrosphere, apologist, humourous, langevin,
# Nearest to more: less, most, very, regency, larger, highly, too, greater,
# Nearest to was: is, had, became, were, has, been, be, missoula,
# Average loss at step 42000: 3.433817
# Average loss at step 44000: 3.457317
# Average loss at step 46000: 3.450205
# Average loss at step 48000: 3.354817
# Average loss at step 50000: 3.382740
# Nearest to first: second, last, same, next, third, gesellschaft, final, touchdowns,
# Nearest to three: four, six, eight, five, seven, two, nine, zero,
# Nearest to had: has, have, was, were, since, having, been, pretenders,
# Nearest to there: they, it, he, she, still, usually, often, who,
# Nearest to with: between, by, gallon, kinshasa, nervous, for, blasted, hoofed,
# Nearest to no: any, little, malawian, supp, charged, dickson, guarantee, creative,
# Nearest to only: leisurely, rated, actually, ceremony, moreover, radiometric, scored, hamper,
# Nearest to four: five, six, eight, three, seven, nine, two, zero,
# Nearest to not: now, almost, wadsworth, still, brownlow, discouraged, inhibited, usually,
# Nearest to so: fixing, before, if, egg, too, quark, invariable, eared,
# Nearest to has: had, have, is, was, having, pretenders, tainted, waited,
# Nearest to such: well, these, known, regarded, many, campaigners, petronas, attractor,
# Nearest to be: have, were, being, was, been, become, flybys, is,
# Nearest to d: b, van, psychotic, inoculated, schiavo, georges, aldrin, activating,
# Nearest to more: less, most, very, highly, larger, fewer, greater, too,
# Nearest to was: is, became, has, were, had, be, by, been,
# Average loss at step 52000: 3.438373
# Average loss at step 54000: 3.428073
# Average loss at step 56000: 3.441255
# Average loss at step 58000: 3.394567
# Average loss at step 60000: 3.391527
# Nearest to first: last, second, same, next, third, only, araki, mouth,
# Nearest to three: five, four, six, eight, two, seven, nine, zero,
# Nearest to had: has, have, was, were, having, been, pretenders, became,
# Nearest to there: they, it, she, still, now, he, often, this,
# Nearest to with: between, kinshasa, titanic, by, overviews, including, under, suburb,
# Nearest to no: any, malawian, little, supp, vantage, provisionally, caving, dickson,
# Nearest to only: leisurely, zedong, loneliness, within, rated, first, transceiver, ceremony,
# Nearest to four: five, six, eight, three, seven, nine, two, zero,
# Nearest to not: still, almost, now, also, usually, wadsworth, to, inhibited,
# Nearest to so: fixing, too, if, fuels, curator, abrogated, entropy, very,
# Nearest to has: had, have, was, is, cga, having, contains, tectonics,
# Nearest to such: well, these, many, known, regarded, campaigners, other, like,
# Nearest to be: been, is, have, become, flybys, being, were, refer,
# Nearest to d: b, van, hitch, psychotic, c, freitas, jackie, gimmicks,
# Nearest to more: less, most, very, highly, larger, rather, fewer, too,
# Nearest to was: is, had, became, has, were, did, been, does,
# Average loss at step 62000: 3.235699
# Average loss at step 64000: 3.255740
# Average loss at step 66000: 3.400073
# Average loss at step 68000: 3.392207
# Average loss at step 70000: 3.361483
# Nearest to first: second, last, same, third, next, final, original, following,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to had: have, has, was, were, having, pretenders, since, wanted,
# Nearest to there: they, it, he, we, she, still, often, now,
# Nearest to with: between, titanic, blasted, incoming, sammon, rescheduled, in, gallon,
# Nearest to no: little, any, there, malawian, garrisoned, guarantee, basically, supp,
# Nearest to only: still, zedong, transceiver, strictly, leisurely, therefore, first, typically,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to not: still, now, usually, discouraged, precautionary, also, headers, inhibited,
# Nearest to so: if, fixing, sometimes, too, curator, mommy, dissection, quark,
# Nearest to has: had, have, is, was, contains, since, equine, having,
# Nearest to such: these, well, known, regarded, campaigners, other, like, many,
# Nearest to be: been, is, become, have, were, being, are, was,
# Nearest to d: b, van, h, gimmicks, hitch, pathogen, georges, monroe,
# Nearest to more: less, most, very, larger, highly, too, rather, fewer,
# Nearest to was: is, has, had, were, became, been, be, castration,
# Average loss at step 72000: 3.370038
# Average loss at step 74000: 3.348760
# Average loss at step 76000: 3.316246
# Average loss at step 78000: 3.352775
# Average loss at step 80000: 3.374856
# Nearest to first: second, last, third, next, final, same, only, araki,
# Nearest to three: five, four, six, seven, two, eight, nine, zero,
# Nearest to had: has, have, were, was, having, became, wanted, pretenders,
# Nearest to there: they, it, he, she, we, still, often, abidjan,
# Nearest to with: between, when, redefining, botched, titanic, blasted, by, calorimeter,
# Nearest to no: little, any, malawian, supp, experiencing, vantage, leger, championships,
# Nearest to only: leisurely, first, loneliness, pleases, cantos, therefore, unarmed, buzzing,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to not: still, usually, nor, always, discouraged, generally, now, easterly,
# Nearest to so: if, curator, fixing, sometimes, then, before, too, quark,
# Nearest to has: had, have, is, was, preserves, contains, freemasons, cga,
# Nearest to such: these, well, regarded, known, dispositions, like, usurp, certain,
# Nearest to be: been, have, being, become, convince, remain, coburg, flybys,
# Nearest to d: b, van, h, et, supposing, g, freitas, f,
# Nearest to more: less, very, most, larger, highly, too, faster, rather,
# Nearest to was: is, became, were, had, when, has, been, although,
# Average loss at step 82000: 3.405594
# Average loss at step 84000: 3.409106
# Average loss at step 86000: 3.388402
# Average loss at step 88000: 3.354207
# Average loss at step 90000: 3.371255
# Nearest to first: last, second, same, final, third, original, next, boy,
# Nearest to three: five, two, four, seven, eight, six, nine, zero,
# Nearest to had: has, have, was, were, having, since, been, tried,
# Nearest to there: they, it, he, still, she, we, sometimes, now,
# Nearest to with: between, in, for, botched, glaring, glencoe, comprising, titanic,
# Nearest to no: little, any, malawian, concerned, than, vantage, only, creative,
# Nearest to only: leisurely, actually, loneliness, therefore, either, cantos, microinstruction, no,
# Nearest to four: five, six, seven, eight, three, two, nine, zero,
# Nearest to not: still, now, discouraged, wadsworth, t, precautionary, they, nor,
# Nearest to so: too, if, before, curator, fixing, felt, hanna, thus,
# Nearest to has: had, have, is, was, having, since, single, contains,
# Nearest to such: well, known, these, regarded, dispositions, usurp, certain, heflin,
# Nearest to be: been, was, become, have, being, is, refer, remain,
# Nearest to d: b, rd, supposing, freitas, h, jackie, dec, lydian,
# Nearest to more: less, larger, very, most, highly, faster, rather, fewer,
# Nearest to was: is, had, were, became, be, been, has, while,
# Average loss at step 92000: 3.398417
# Average loss at step 94000: 3.256421
# Average loss at step 96000: 3.357114
# Average loss at step 98000: 3.239630
# Average loss at step 100000: 3.353712
# Nearest to first: last, second, next, third, final, same, original, fourth,
# Nearest to three: four, five, six, two, eight, seven, nine, zero,
# Nearest to had: has, have, was, were, having, since, could, would,
# Nearest to there: they, it, he, we, still, she, often, sometimes,
# Nearest to with: between, including, when, glencoe, in, unlike, baltasar, titanic,
# Nearest to no: little, any, creative, malawian, supp, concerned, experiencing, reconnection,
# Nearest to only: leisurely, actually, unarmed, microinstruction, approximately, samos, radiometric, not,
# Nearest to four: five, six, eight, seven, three, two, nine, zero,
# Nearest to not: never, still, now, nor, librarian, precautionary, actually, easterly,
# Nearest to so: too, when, thus, fixing, sometimes, then, curator, if,
# Nearest to has: had, have, is, was, since, having, lauder, contains,
# Nearest to such: well, known, these, dispositions, regarded, seen, usurp, many,
# Nearest to be: been, have, become, refer, remain, are, flybys, is,
# Nearest to d: b, supposing, h, reductive, freitas, pathogen, picks, judoka,
# Nearest to more: less, most, larger, very, highly, faster, stronger, fewer,
# Nearest to was: is, became, had, has, were, when, been, becomes,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
