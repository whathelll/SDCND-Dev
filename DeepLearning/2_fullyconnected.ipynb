# %% [markdown]
# Deep Learning
# =============
#
# Assignment 2
# ------------
#
# Previously in `1_notmnist.ipynb`, we created a pickle with formatted datasets for training, development and testing on the [notMNIST dataset](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html).
#
# The goal of this assignment is to progressively train deeper and more accurate models using TensorFlow.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %% [markdown]
# First reload the data we generated in `1_notmnist.ipynb`.

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a shape that's more adapted to the models we're going to train:
# - data as a flat matrix,
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10

def reformat(dataset, labels):
  dataset = dataset.reshape((-1, image_size * image_size)).astype(np.float32)
  # Map 0 to [1.0, 0.0, 0.0 ...], 1 to [0.0, 1.0, 0.0 ...]
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 784) (200000, 10)
# Validation set (10000, 784) (10000, 10)
# Test set (10000, 784) (10000, 10)

# %% [markdown]
# We're first going to train a multinomial logistic regression using simple gradient descent.
#
# TensorFlow works like this:
# * First you describe the computation that you want to see performed: what the inputs, the variables, and the operations look like. These get created as nodes over a computation graph. This description is all contained within the block below:
#
#       with graph.as_default():
#           ...
#
# * Then you can run the operations on this graph as many times as you want by calling `session.run()`, providing it outputs to fetch from the graph that get returned. This runtime operation is all contained in the block below:
#
#       with tf.Session(graph=graph) as session:
#           ...
#
# Let's load all the data into TensorFlow and build the computation graph corresponding to our training:

# %%
# With gradient descent training, even this much data is prohibitive.
# Subset the training data for faster turnaround.
train_subset = 10000

graph = tf.Graph()
with graph.as_default():

  # Input data.
  # Load the training, validation and test data into constants that are
  # attached to the graph.
  tf_train_dataset = tf.constant(train_dataset[:train_subset, :])
  tf_train_labels = tf.constant(train_labels[:train_subset])
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  # These are the parameters that we are going to be training. The weight
  # matrix will be initialized using random values following a (truncated)
  # normal distribution. The biases get initialized to zero.
  weights = tf.Variable(
    tf.truncated_normal([image_size * image_size, num_labels]))
  biases = tf.Variable(tf.zeros([num_labels]))
  
  # Training computation.
  # We multiply the inputs with the weight matrix, and add biases. We compute
  # the softmax and cross-entropy (it's one operation in TensorFlow, because
  # it's very common, and it can be optimized). We take the average of this
  # cross-entropy across all training examples: that's our loss.
  logits = tf.matmul(tf_train_dataset, weights) + biases
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
  
  # Optimizer.
  # We are going to find the minimum of this loss using gradient descent.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  # These are not part of training, but merely here so that we can report
  # accuracy figures as we train.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(
    tf.matmul(tf_valid_dataset, weights) + biases)
  test_prediction = tf.nn.softmax(tf.matmul(tf_test_dataset, weights) + biases)

# %% [markdown]
# Let's run this computation and iterate:

# %%
num_steps = 801

def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

with tf.Session(graph=graph) as session:
  # This is a one-time operation which ensures the parameters get initialized as
  # we described in the graph: random weights for the matrix, zeros for the
  # biases. 
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    # Run the computations. We tell .run() that we want to run the optimizer,
    # and get the loss value and the training predictions returned as numpy
    # arrays.
    _, l, predictions = session.run([optimizer, loss, train_prediction])
    if (step % 100 == 0):
      print('Loss at step %d: %f' % (step, l))
      print('Training accuracy: %.1f%%' % accuracy(
        predictions, train_labels[:train_subset, :]))
      # Calling .eval() on valid_prediction is basically like calling run(), but
      # just to get that one numpy array. Note that it recomputes all its graph
      # dependencies.
      print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Loss at step 0: 17.863066
# Training accuracy: 13.3%
# Validation accuracy: 16.4%
# Loss at step 100: 2.236941
# Training accuracy: 72.2%
# Validation accuracy: 70.3%
# Loss at step 200: 1.790084
# Training accuracy: 75.3%
# Validation accuracy: 73.0%
# Loss at step 300: 1.559307
# Training accuracy: 76.6%
# Validation accuracy: 73.9%
# Loss at step 400: 1.403725
# Training accuracy: 77.5%
# Validation accuracy: 74.4%
# Loss at step 500: 1.287907
# Training accuracy: 78.2%
# Validation accuracy: 74.6%
# Loss at step 600: 1.197089
# Training accuracy: 78.6%
# Validation accuracy: 74.8%
# Loss at step 700: 1.123183
# Training accuracy: 79.2%
# Validation accuracy: 75.1%
# Loss at step 800: 1.061350
# Training accuracy: 79.7%
# Validation accuracy: 75.2%
# Test accuracy: 83.0%

# %% [markdown]
# Let's now switch to stochastic gradient descent training instead, which is much faster.
#
# The graph will be similar, except that instead of holding all the training data into a constant node, we create a `Placeholder` node which will be fed actual data at every call of `session.run()`.

# %%
batch_size = 128

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  weights = tf.Variable(
    tf.truncated_normal([image_size * image_size, num_labels]))
  biases = tf.Variable(tf.zeros([num_labels]))
  
  # Training computation.
  logits = tf.matmul(tf_train_dataset, weights) + biases
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
  
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(
    tf.matmul(tf_valid_dataset, weights) + biases)
  test_prediction = tf.nn.softmax(tf.matmul(tf_test_dataset, weights) + biases)

# %% [markdown]
# Let's run it:

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 18.626343
# Minibatch accuracy: 11.7%
# Validation accuracy: 17.2%
# Minibatch loss at step 500: 1.311035
# Minibatch accuracy: 78.1%
# Validation accuracy: 75.8%
# Minibatch loss at step 1000: 1.901275
# Minibatch accuracy: 67.2%
# Validation accuracy: 77.1%
# Minibatch loss at step 1500: 1.429946
# Minibatch accuracy: 69.5%
# Validation accuracy: 77.5%
# Minibatch loss at step 2000: 1.301991
# Minibatch accuracy: 70.3%
# Validation accuracy: 77.9%
# Minibatch loss at step 2500: 0.455604
# Minibatch accuracy: 86.7%
# Validation accuracy: 78.1%
# Minibatch loss at step 3000: 0.964776
# Minibatch accuracy: 78.9%
# Validation accuracy: 78.5%
# Test accuracy: 85.4%

# %% [markdown]
# ---
# Problem
# -------
#
# Turn the logistic regression example with SGD into a 1-hidden layer neural network with rectified linear units [nn.relu()](https://www.tensorflow.org/versions/r0.7/api_docs/python/nn.html#relu) and 1024 hidden nodes. This model should improve your validation / test accuracy.
#
# ---

# %%
batch_size = 256
# print(28*28)
graph = tf.Graph()
with graph.as_default():
    # Input data. For the training data, we use a placeholder that will be fed
    # at run time with a training minibatch.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(None, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(None, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    tf_training = tf.placeholder(tf.bool)

    # Variables.
#     weights = tf.Variable(tf.truncated_normal([image_size * image_size, num_labels]))
#     biases = tf.Variable(tf.zeros([num_labels]))

    def getLogits(inputs):
        #hidden layer
        hidden = tf.layers.dense(inputs=inputs, units=1024)
        hidden = tf.layers.batch_normalization(hidden)
        hidden = tf.nn.relu(hidden)
        hidden = tf.layers.dropout(inputs=hidden,rate=0.25,noise_shape=None,seed=None,training=tf_training,name=None)
        
        hidden = tf.layers.dense(inputs=hidden, units=512)
        hidden = tf.layers.batch_normalization(hidden)
        hidden = tf.nn.relu(hidden)
        hidden = tf.layers.dropout(inputs=hidden,rate=0.25,noise_shape=None,seed=None,training=tf_training,name=None)
        
        hidden = tf.layers.dense(inputs=hidden, units=256)
        hidden = tf.layers.batch_normalization(hidden)
        hidden = tf.nn.relu(hidden)
        hidden = tf.layers.dropout(inputs=hidden,rate=0.25,noise_shape=None,seed=None,training=tf_training,name=None)
        
        hidden = tf.layers.dense(inputs=hidden, units=128)
        hidden = tf.layers.batch_normalization(hidden)
        hidden = tf.nn.relu(hidden)
        hidden = tf.layers.dropout(inputs=hidden,rate=0.25,noise_shape=None,seed=None,training=tf_training,name=None)
        
        hidden = tf.layers.dense(inputs=hidden, units=64)
        hidden = tf.layers.batch_normalization(hidden)
        hidden = tf.nn.relu(hidden)
        hidden = tf.layers.dropout(inputs=hidden,rate=0.25,noise_shape=None,seed=None,training=tf_training,name=None)
        
        # Training computation.
        logits = tf.layers.dense(inputs=hidden, units=10, activation=tf.nn.relu)
        return logits
    
    logits = getLogits(tf_train_dataset)
    
    
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))

    
    global_step = tf.Variable(0, trainable=False)
    starter_learning_rate = 0.1
    learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step, 5000, 0.8, staircase=True)
#     optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
#     valid_prediction = tf.nn.softmax(tf_valid_dataset, False))
    valid_prediction = tf.nn.softmax(logits)
#     test_prediction = tf.nn.softmax(getLogits(tf_test_dataset, False))
    test_prediction = tf.nn.softmax(logits)

# %%
num_steps = 50001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print("Initialized")
    for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        # Generate a minibatch.
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        # Prepare a dictionary telling the session where to feed the minibatch.
        # The key of the dictionary is the placeholder node of the graph to be fed,
        # and the value is the numpy array to feed to it.
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, tf_training: True}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 1000 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Learning rate: %f, Global Step: %d" % (learning_rate.eval(), global_step.eval()))
            print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
            feed_dict = {tf_train_dataset : valid_dataset, tf_train_labels : valid_labels, tf_training: False}
            print("Validation accuracy: %.1f%%" % accuracy(session.run(valid_prediction, feed_dict=feed_dict), valid_labels))
    feed_dict = {tf_train_dataset : test_dataset, tf_train_labels : test_labels, tf_training: False} 
    print("Test accuracy: %.1f%%" % accuracy(session.run(test_prediction, feed_dict=feed_dict), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.332266
# Learning rate: 0.100000, Global Step: 1
# Minibatch accuracy: 13.7%
# Validation accuracy: 12.7%
# Minibatch loss at step 500: 0.673579
# Learning rate: 0.100000, Global Step: 501
# Minibatch accuracy: 78.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 1000: 0.464870
# Learning rate: 0.100000, Global Step: 1001
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.8%
# Minibatch loss at step 1500: 0.415004
# Learning rate: 0.100000, Global Step: 1501
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 2000: 0.501562
# Learning rate: 0.100000, Global Step: 2001
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.7%
# Minibatch loss at step 2500: 0.410200
# Learning rate: 0.100000, Global Step: 2501
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.5%
# Minibatch loss at step 3000: 0.475501
# Learning rate: 0.100000, Global Step: 3001
# Minibatch accuracy: 84.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 3500: 0.375188
# Learning rate: 0.100000, Global Step: 3501
# Minibatch accuracy: 87.9%
# Validation accuracy: 88.7%
# Minibatch loss at step 4000: 0.448626
# Learning rate: 0.100000, Global Step: 4001
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.1%
# Minibatch loss at step 4500: 0.366069
# Learning rate: 0.100000, Global Step: 4501
# Minibatch accuracy: 90.2%
# Validation accuracy: 89.5%
# Minibatch loss at step 5000: 0.347321
# Learning rate: 0.080000, Global Step: 5001
# Minibatch accuracy: 89.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 5500: 0.359074
# Learning rate: 0.080000, Global Step: 5501
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.9%
# Minibatch loss at step 6000: 0.247675
# Learning rate: 0.080000, Global Step: 6001
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.9%
# Minibatch loss at step 6500: 0.314127
# Learning rate: 0.080000, Global Step: 6501
# Minibatch accuracy: 91.0%
# Validation accuracy: 90.0%
# Minibatch loss at step 7000: 0.329396
# Learning rate: 0.080000, Global Step: 7001
# Minibatch accuracy: 90.2%
# Validation accuracy: 90.1%
# Minibatch loss at step 7500: 0.482723
# Learning rate: 0.080000, Global Step: 7501
# Minibatch accuracy: 83.6%
# Validation accuracy: 90.3%
# Minibatch loss at step 8000: 0.384911
# Learning rate: 0.080000, Global Step: 8001
# Minibatch accuracy: 87.9%
# Validation accuracy: 90.3%
# Minibatch loss at step 8500: 0.383833
# Learning rate: 0.080000, Global Step: 8501
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.4%
# Minibatch loss at step 9000: 0.255954
# Learning rate: 0.080000, Global Step: 9001
# Minibatch accuracy: 92.6%
# Validation accuracy: 90.6%
# Minibatch loss at step 9500: 0.298596
# Learning rate: 0.080000, Global Step: 9501
# Minibatch accuracy: 90.2%
# Validation accuracy: 90.7%
# Minibatch loss at step 10000: 0.284287
# Learning rate: 0.064000, Global Step: 10001
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.6%
# Minibatch loss at step 10500: 0.282794
# Learning rate: 0.064000, Global Step: 10501
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.7%
# Minibatch loss at step 11000: 0.342148
# Learning rate: 0.064000, Global Step: 11001
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.7%
# Minibatch loss at step 11500: 0.372078
# Learning rate: 0.064000, Global Step: 11501
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 12000: 0.339293
# Learning rate: 0.064000, Global Step: 12001
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.9%
# Minibatch loss at step 12500: 0.263623
# Learning rate: 0.064000, Global Step: 12501
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.9%
# Minibatch loss at step 13000: 0.261417
# Learning rate: 0.064000, Global Step: 13001
# Minibatch accuracy: 92.6%
# Validation accuracy: 91.0%
# Minibatch loss at step 13500: 0.246379
# Learning rate: 0.064000, Global Step: 13501
# Minibatch accuracy: 93.4%
# Validation accuracy: 91.0%
# Minibatch loss at step 14000: 0.205834
# Learning rate: 0.064000, Global Step: 14001
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.0%
# Minibatch loss at step 14500: 0.263303
# Learning rate: 0.064000, Global Step: 14501
# Minibatch accuracy: 93.4%
# Validation accuracy: 91.1%
# Minibatch loss at step 15000: 0.242239
# Learning rate: 0.051200, Global Step: 15001
# Minibatch accuracy: 91.8%
# Validation accuracy: 90.9%
# Minibatch loss at step 15500: 0.208870
# Learning rate: 0.051200, Global Step: 15501
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.2%
# Minibatch loss at step 16000: 0.215148
# Learning rate: 0.051200, Global Step: 16001
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.2%
# Minibatch loss at step 16500: 0.204333
# Learning rate: 0.051200, Global Step: 16501
# Minibatch accuracy: 93.4%
# Validation accuracy: 91.2%
# Minibatch loss at step 17000: 0.329067
# Learning rate: 0.051200, Global Step: 17001
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.2%
# Minibatch loss at step 17500: 0.265415
# Learning rate: 0.051200, Global Step: 17501
# Minibatch accuracy: 91.8%
# Validation accuracy: 91.3%
# Minibatch loss at step 18000: 0.250599
# Learning rate: 0.051200, Global Step: 18001
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.3%
# Minibatch loss at step 18500: 0.224311
# Learning rate: 0.051200, Global Step: 18501
# Minibatch accuracy: 93.4%
# Validation accuracy: 91.3%
# Minibatch loss at step 19000: 0.227095
# Learning rate: 0.051200, Global Step: 19001
# Minibatch accuracy: 92.6%
# Validation accuracy: 91.2%
# Minibatch loss at step 19500: 0.230368
# Learning rate: 0.051200, Global Step: 19501
# Minibatch accuracy: 92.6%
# Validation accuracy: 91.3%
# Minibatch loss at step 20000: 0.232705
# Learning rate: 0.040960, Global Step: 20001
# Minibatch accuracy: 93.4%
# Validation accuracy: 91.5%
# Minibatch loss at step 20500: 0.182054
# Learning rate: 0.040960, Global Step: 20501
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.2%
# Minibatch loss at step 21000: 0.192875
# Learning rate: 0.040960, Global Step: 21001
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.2%
# Minibatch loss at step 21500: 0.180330
# Learning rate: 0.040960, Global Step: 21501
# Minibatch accuracy: 94.9%
# Validation accuracy: 91.4%
# Minibatch loss at step 22000: 0.208584
# Learning rate: 0.040960, Global Step: 22001
# Minibatch accuracy: 92.6%
# Validation accuracy: 91.4%
# Minibatch loss at step 22500: 0.241579
# Learning rate: 0.040960, Global Step: 22501
# Minibatch accuracy: 93.4%
# Validation accuracy: 91.2%
# Minibatch loss at step 23000: 0.216111
# Learning rate: 0.040960, Global Step: 23001
# Minibatch accuracy: 94.1%
# Validation accuracy: 91.4%
# Minibatch loss at step 23500: 0.260404
# Learning rate: 0.040960, Global Step: 23501
# Minibatch accuracy: 91.8%
# Validation accuracy: 91.3%
# Minibatch loss at step 24000: 0.179613
# Learning rate: 0.040960, Global Step: 24001
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.4%
# Minibatch loss at step 24500: 0.138230
# Learning rate: 0.040960, Global Step: 24501
# Minibatch accuracy: 94.9%
# Validation accuracy: 91.5%
# Minibatch loss at step 25000: 0.182399
# Learning rate: 0.032768, Global Step: 25001
# Minibatch accuracy: 94.9%
# Validation accuracy: 91.5%
# Minibatch loss at step 25500: 0.211728
# Learning rate: 0.032768, Global Step: 25501
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.6%
# Minibatch loss at step 26000: 0.193574
# Learning rate: 0.032768, Global Step: 26001
# Minibatch accuracy: 93.4%
# Validation accuracy: 91.5%
# Minibatch loss at step 26500: 0.197405
# Learning rate: 0.032768, Global Step: 26501
# Minibatch accuracy: 94.9%
# Validation accuracy: 91.5%
# Minibatch loss at step 27000: 0.259274
# Learning rate: 0.032768, Global Step: 27001
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 27500: 0.169324
# Learning rate: 0.032768, Global Step: 27501
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.6%
# Minibatch loss at step 28000: 0.224683
# Learning rate: 0.032768, Global Step: 28001
# Minibatch accuracy: 91.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 28500: 0.283401
# Learning rate: 0.032768, Global Step: 28501
# Minibatch accuracy: 91.0%
# Validation accuracy: 91.6%
# Minibatch loss at step 29000: 0.186347
# Learning rate: 0.032768, Global Step: 29001
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.6%
# Minibatch loss at step 29500: 0.217198
# Learning rate: 0.032768, Global Step: 29501
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.5%
# Minibatch loss at step 30000: 0.173962
# Learning rate: 0.026214, Global Step: 30001
# Minibatch accuracy: 94.9%
# Validation accuracy: 91.5%
# Minibatch loss at step 30500: 0.220044
# Learning rate: 0.026214, Global Step: 30501
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.5%
# Minibatch loss at step 31000: 0.209857
# Learning rate: 0.026214, Global Step: 31001
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.6%
# Minibatch loss at step 31500: 0.262078
# Learning rate: 0.026214, Global Step: 31501
# Minibatch accuracy: 91.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 32000: 0.224036
# Learning rate: 0.026214, Global Step: 32001
# Minibatch accuracy: 91.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 32500: 0.199675
# Learning rate: 0.026214, Global Step: 32501
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 33000: 0.271767
# Learning rate: 0.026214, Global Step: 33001
# Minibatch accuracy: 91.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 33500: 0.243150
# Learning rate: 0.026214, Global Step: 33501
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 34000: 0.197738
# Learning rate: 0.026214, Global Step: 34001
# Minibatch accuracy: 93.4%
# Validation accuracy: 91.7%
# Minibatch loss at step 34500: 0.271197
# Learning rate: 0.026214, Global Step: 34501
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.7%
# Minibatch loss at step 35000: 0.114227
# Learning rate: 0.020972, Global Step: 35001
# Minibatch accuracy: 96.5%
# Validation accuracy: 91.7%
# Minibatch loss at step 35500: 0.154508
# Learning rate: 0.020972, Global Step: 35501
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.6%
# Minibatch loss at step 36000: 0.215683
# Learning rate: 0.020972, Global Step: 36001
# Minibatch accuracy: 93.4%
# Validation accuracy: 91.5%
# Minibatch loss at step 36500: 0.142525
# Learning rate: 0.020972, Global Step: 36501
# Minibatch accuracy: 96.5%
# Validation accuracy: 91.6%
# Minibatch loss at step 37000: 0.225374
# Learning rate: 0.020972, Global Step: 37001
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.6%
# Minibatch loss at step 37500: 0.160998
# Learning rate: 0.020972, Global Step: 37501
# Minibatch accuracy: 94.1%
# Validation accuracy: 91.6%
# Minibatch loss at step 38000: 0.235455
# Learning rate: 0.020972, Global Step: 38001
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 38500: 0.139837
# Learning rate: 0.020972, Global Step: 38501
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.5%
# Minibatch loss at step 39000: 0.151055
# Learning rate: 0.020972, Global Step: 39001
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.6%
# Minibatch loss at step 39500: 0.110466
# Learning rate: 0.020972, Global Step: 39501
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.6%
# Minibatch loss at step 40000: 0.173883
# Learning rate: 0.016777, Global Step: 40001
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.6%
# Minibatch loss at step 40500: 0.135655
# Learning rate: 0.016777, Global Step: 40501
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 41000: 0.143879
# Learning rate: 0.016777, Global Step: 41001
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.6%
# Minibatch loss at step 41500: 0.144293
# Learning rate: 0.016777, Global Step: 41501
# Minibatch accuracy: 94.9%
# Validation accuracy: 91.7%
# Minibatch loss at step 42000: 0.125051
# Learning rate: 0.016777, Global Step: 42001
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.6%
# Minibatch loss at step 42500: 0.154021
# Learning rate: 0.016777, Global Step: 42501
# Minibatch accuracy: 95.7%
# Validation accuracy: 91.7%
# Minibatch loss at step 43000: 0.169375
# Learning rate: 0.016777, Global Step: 43001
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.8%
# Minibatch loss at step 43500: 0.203483
# Learning rate: 0.016777, Global Step: 43501
# Minibatch accuracy: 94.9%
# Validation accuracy: 91.7%
# Minibatch loss at step 44000: 0.202084
# Learning rate: 0.016777, Global Step: 44001
# Minibatch accuracy: 93.4%
# Validation accuracy: 91.7%
# Minibatch loss at step 44500: 0.164665
# Learning rate: 0.016777, Global Step: 44501
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.8%
# Minibatch loss at step 45000: 0.148046
# Learning rate: 0.013422, Global Step: 45001
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 45500: 0.149434
# Learning rate: 0.013422, Global Step: 45501
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 46000: 0.267474
# Learning rate: 0.013422, Global Step: 46001
# Minibatch accuracy: 90.2%
# Validation accuracy: 91.8%
# Minibatch loss at step 46500: 0.152002
# Learning rate: 0.013422, Global Step: 46501
# Minibatch accuracy: 95.7%
# Validation accuracy: 91.6%
# Minibatch loss at step 47000: 0.163663
# Learning rate: 0.013422, Global Step: 47001
# Minibatch accuracy: 95.7%
# Validation accuracy: 91.7%
# Minibatch loss at step 47500: 0.173839
# Learning rate: 0.013422, Global Step: 47501
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.7%
# Minibatch loss at step 48000: 0.252027
# Learning rate: 0.013422, Global Step: 48001
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.6%
# Minibatch loss at step 48500: 0.250370
# Learning rate: 0.013422, Global Step: 48501
# Minibatch accuracy: 94.1%
# Validation accuracy: 91.8%
# Minibatch loss at step 49000: 0.142818
# Learning rate: 0.013422, Global Step: 49001
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 49500: 0.152921
# Learning rate: 0.013422, Global Step: 49501
# Minibatch accuracy: 94.9%
# Validation accuracy: 91.7%
# Minibatch loss at step 50000: 0.165215
# Learning rate: 0.010737, Global Step: 50001
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.7%
# Test accuracy: 96.3%
